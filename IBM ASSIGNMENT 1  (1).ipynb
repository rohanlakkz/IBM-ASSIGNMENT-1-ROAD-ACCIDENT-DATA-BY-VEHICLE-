# %% [markdown]
# # Name : ROHAN ASHOK LAKKAMPALLI
# B.TECH AIML SEM2 SEC:C BATCH:C2 ROLL NO:65

# %% [markdown]
# # 1.READ THE GIVEN CSV FILE

# %%
import pandas as pd
df=pd.read_csv(" road accident data.csv")
df
# Out:
#                                              Location  Motor Car  \
# 0                                              Ampara         59
# 1                                        Anuradhapura        116
# 2           Badulla (Badulla & Bandarawela Divisions)         82
# 3                                          Batticaloa         26
# 4                Chilaw (Chilaw & Puttalam Divisions)        102
# 5   Colombo (Colombo-South, North, Central, Mt. La...       4708
# 6                  Galle (Galle & Elpitiya Divisions)        488
# 7     Gampaha (Gampaha, Negombo & Kelaniya Divisions)       2018
# 8                     Jaffna (Jaffna & KKS Divisions)         32
# 9            Kalutara (Kalutara & Panadura Divisions)        381
# 10                  Kandy (Kandy & Gampola Divisions)        735
# 11           Kegalle (Kegalle & Seethawaka Divisions)        281
# 12     Kilinochchi (Kilinochchi & Mankulam Divisions)          5
# ...

# %% [markdown]
# # 2.SET THE INDEX

# %%
 df.set_index('Location',inplace=True)
df.head(10)
# Out:
#                                                     Motor Car  \
# Location
# Ampara                                                     59
# Anuradhapura                                              116
# Badulla (Badulla & Bandarawela Divisions)                  82
# Batticaloa                                                 26
# Chilaw (Chilaw & Puttalam Divisions)                      102
# Colombo (Colombo-South, North, Central, Mt. Lav...       4708
# Galle (Galle & Elpitiya Divisions)                        488
# Gampaha (Gampaha, Negombo & Kelaniya Divisions)          2018
# Jaffna (Jaffna & KKS Divisions)                            32
# Kalutara (Kalutara & Panadura Divisions)                  381
#
#                                                     Dual Purpose Vehicle  \
# Location
# Ampara                                                               102
# Anuradhapura                                                         224
# ...

# %% [markdown]
# # 3.WRITE THE CODE TO DISPLAY THE FOLLOWING OUTPUT

# %% [markdown]
# 1. MULTIPLE COLUMNS

# %%
MotorCarAndCycle_Data=df[["Motor Car","Cycle"]]
MotorCarAndCycle_Data
# Out:
#                                                     Motor Car  Cycle
# Location
# Ampara                                                     59     93
# Anuradhapura                                              116    158
# Badulla (Badulla & Bandarawela Divisions)                  82     20
# Batticaloa                                                 26     64
# Chilaw (Chilaw & Puttalam Divisions)                      102    134
# Colombo (Colombo-South, North, Central, Mt. Lav...       4708    221
# Galle (Galle & Elpitiya Divisions)                        488    216
# Gampaha (Gampaha, Negombo & Kelaniya Divisions)          2018    317
# Jaffna (Jaffna & KKS Divisions)                            32     73
# Kalutara (Kalutara & Panadura Divisions)                  381    226
# Kandy (Kandy & Gampola Divisions)                         735     29
# Kegalle (Kegalle & Seethawaka Divisions)                  281     23
# ...

# %% [markdown]
# 2. MULTIPLE ROWS

# %%
AmparaAndAnuradhapura_Data=df.loc[["Amparad","Anuradhapura"]]
AmparaAndAnuradhapura_Data
# Out:
#               Motor Car  Dual Purpose Vehicle  Lorry  Cycle  \
# Location
# Ampara               59                   102    121     93
# Anuradhapura        116                   224    246    158
#
#               Motor Cycle/Moped  Three wheeler  \
# Location
# Ampara                      575            169
# Anuradhapura                845            196
#
#               Articulated Vehicle, prime mover  SLT Bus  Private Bus  \
# Location
# Ampara                                       4       15           35
# Anuradhapura                                 2       28          104
#
#               Intercity Bus  Land Vehicle/Tractor  \
# Location
# Ampara                    1                    41
# Anuradhapura              3                    72
#
#               Animal drawn vehicle or rider on animal  Other
# Location
# Ampara                                              4      0
# Anuradhapura                                        0      6

# %% [markdown]
# 3. MULTIPLE ROWS AND MULTIPLE COLUMNS

# %%
df.loc[["Ampara","Mannar","Matara",],["Lorry","Cycle"]]
# Out:
#           Lorry  Cycle
# Location
# Ampara      121     93
# Mannar       26     18
# Matara      163    107

# %% [markdown]
# 4. ALL THE ROWS AND SOME COLUMNS

# %%
df.loc[:,["SLT Bus","Private Bus","Intercity Bus"]]
# Out:
#                                                     SLT Bus  Private Bus  \
# Location
# Ampara                                                   15           35
# Anuradhapura                                             28          104
# Badulla (Badulla & Bandarawela Divisions)                58           78
# Batticaloa                                                9           25
# Chilaw (Chilaw & Puttalam Divisions)                     23           84
# Colombo (Colombo-South, North, Central, Mt. Lav...      190         1194
# Galle (Galle & Elpitiya Divisions)                       73          224
# Gampaha (Gampaha, Negombo & Kelaniya Divisions)         123          590
# Jaffna (Jaffna & KKS Divisions)                           8           21
# Kalutara (Kalutara & Panadura Divisions)                 53          238
# Kandy (Kandy & Gampola Divisions)                       148          403
# Kegalle (Kegalle & Seethawaka Divisions)                 82          224
# ...

# %% [markdown]
# 5. SOME ROWS AND ALL THE COLUMNS

# %%
df.loc[["Polonnaruwa","Ratnapura","Vavuniya"],:]
# Out:
#              Motor Car  Dual Purpose Vehicle  Lorry  Cycle  Motor Cycle/Moped  \
# Location
# Polonnaruwa         36                    92    136     63                348
# Ratnapura          182                   234    321     42                553
# Vavuniya             4                    15     32     26                 66
#
#              Three wheeler  Articulated Vehicle, prime mover  SLT Bus  \
# Location
# Polonnaruwa             95                                 1       18
# Ratnapura              443                                 9       38
# Vavuniya                20                                 0        3
#
#              Private Bus  Intercity Bus  Land Vehicle/Tractor  \
# Location
# Polonnaruwa           31              1                    36
# Ratnapura            155              2                     8
# Vavuniya               3              0                     2
#
#              Animal drawn vehicle or rider on animal  Other
# Location
# ...
